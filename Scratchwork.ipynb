# %% [markdown]
# # Scratchwork to clean the data files so they can be imported to postgresql

# %% [raw]
# import pandas as pd
# import os

# %%
folder_path = "sample_data"

files = [
    f for f in os.listdir(folder_path)
    if os.path.isfile(os.path.join(folder_path, f))
]


for filename in files:
    df = pd.read_csv('sample_data/'+filename)
    df["amount"] = pd.to_numeric(df["amount"], errors="coerce")
    df = df.dropna(subset=["merchant_id"])
    df.drop(df[df["event_timestamp"] == "NOT-A-DATE"].index, inplace=True)
    df.to_csv("clean_data/"+filename, index=False)
# Out:
# ['activities_20240101.csv', 'activities_20240102.csv', 'activities_20240103.csv', 'activities_20240104.csv', 'activities_20240105.csv', 'activities_20240106.csv', 'activities_20240107.csv', 'activities_20240108.csv', 'activities_20240109.csv', 'activities_20240110.csv', 'activities_20240111.csv', 'activities_20240112.csv', 'activities_20240113.csv', 'activities_20240114.csv', 'activities_20240115.csv', 'activities_20240116.csv', 'activities_20240117.csv', 'activities_20240118.csv', 'activities_20240119.csv', 'activities_20240120.csv', 'activities_20240121.csv', 'activities_20240122.csv', 'activities_20240123.csv', 'activities_20240124.csv', 'activities_20240125.csv', 'activities_20240126.csv', 'activities_20240127.csv', 'activities_20240128.csv', 'activities_20240129.csv', 'activities_20240130.csv', 'activities_20240131.csv']

# %% [markdown]
# # Scratchwork to connect the database to python

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # automatically loads .env from current directory

database = os.getenv("DATABASE")
user = os.getenv("USER")
password= os.getenv("PASSWORD")
table_name = os.getenv("TABLE_NAME")

# %%
import psycopg2

# Connect to PostgreSQL
conn = psycopg2.connect(
    host="localhost",
    database=database,
    user=user,
    password=password
)
cursor = conn.cursor()

# %%
# Execute a query
cursor.execute(f"SELECT * FROM {table_name}", (30,))

# Fetch results
rows = cursor.fetchmany(100) # changed this from fetchall(100) 

for row in rows:
    print(row)
# Out:
# ('fc5a90a4-26c8-497a-9daa-dbd9af0fc2a9', 'MRC-000001', None, 'POS', 'CARD_TRANSACTION', Decimal('1000.0'), 'SUCCESS', 'POS', 'LAGOS', 'VERIFIED')
# ('fab56e86-398c-4e40-8709-2fb3e1a54a04', 'MRC-000001', datetime.datetime(2024, 1, 1, 10, 0), 'POS', 'CARD_TRANSACTION', None, 'SUCCESS', 'POS', 'LAGOS', 'VERIFIED')
# ('fbd09480-c00b-44cf-920d-6625d2550df8', 'MRC-000001', datetime.datetime(2024, 1, 1, 10, 0), 'POS', 'CARD_TRANSACTION', None, 'SUCCESS', 'POS', 'LAGOS', 'VERIFIED')
# ('2de1bee9-a0f4-488c-ba13-6eaa82b4416d', 'MRC-001396', datetime.datetime(2024, 1, 31, 0, 0, 24), 'CARD_PAYMENT', 'INVOICE_PAYMENT', Decimal('771420.08'), 'SUCCESS', 'WEB', 'ABUJA', 'VERIFIED')
# ('16dec229-78af-4371-a601-2bd74d362898', 'MRC-001221', datetime.datetime(2024, 1, 31, 0, 0, 37), 'POS', 'CARD_TRANSACTION', Decimal('36304.86'), 'SUCCESS', 'POS', 'IBADAN', 'PREMIUM')
# ('d5e58397-cb50-457a-88aa-b2aa2b0aaf26', 'MRC-005718', datetime.datetime(2024, 1, 31, 0, 0, 37), 'SAVINGS', 'DEPOSIT', Decimal('53172.09'), 'SUCCESS', 'APP', 'DELTA', 'VERIFIED')
# ('095b127a-b547-472f-b258-5d3a19a9454d', 'MRC-004165', datetime.datetime(2024, 1, 31, 0, 1, 15), 'MONIEBOOK', 'INVENTORY_UPDATE', Decimal
# ('ca4dd8da-58e2-4d16-a5ea-16090fd77843', 'MRC-002011', datetime.datetime(2024, 1, 31, 0, 9, 7), 'AIRTIME', 'DATA_PURCHASE', Decimal('1341.33'), 'SUCCESS', 'APP', 'IBADAN', 'VERIFIED')
# ('bd82f750-d630-4025-90a1-fff4b5ee739d', 'MRC-009866', datetime.datetime(2024, 1, 31, 0, 9, 20), 'POS', 'CASH_WITHDRAWAL', Decimal('38496.86'), 'SUCCESS', 'POS', 'RIVERS', 'VERIFIED')
# ('eb08f788-9eac-4661-908c-41aa27d34e57', 'MRC-007810', datetime.datetime(2024, 1, 31, 0, 9, 25), 'KYC', 'VERIFICATION_COMPLETED', Decimal('0.0'), 'SUCCESS', 'APP', 'DELTA', 'PREMIUM')
# ('2d731f36-ddb4-41ae-9d17-446dcd2928a8', 'MRC-009260', datetime.datetime(2024, 1, 31, 0, 9, 30), 'POS', 'CARD_TRANSACTION', Decimal('44950.7'), 'SUCCESS', 'POS', 'KANO', 'STARTER')
# ('8dadc0e7-773e-4ad4-a813-56f30034d48b', 'MRC-001054', datetime.datetime(2024, 1, 31, 0, 9, 37), 'CARD_PAYMENT', 'SUPPLIER_PAYMENT', Decimal('355985.72'), 'SUCCESS', 'POS', 'DELTA', 'VERIFIED')
# ('51c0b21e-c371-455d-a95a-da25bdc69bdc', 'MRC-009536', datetime.datetime(2024, 1, 31, 0, 9, 44), 'BILLS', 'CABLE_TV', Decimal('6921.03'), 'SUCCESS', 'APP', 'PORT_HARCOURT', 'PREMIUM')
# ('744f73b3-25e3-4b41-9eeb-440d73a6eb69', 'MRC-007718', datetime.datetime(2024, 1, 31, 0, 9, 47), 'POS', 'CARD_TRANSACTION', Decimal('175271.91'), 'SUCCESS', 'POS', 'DELTA', 'VERIFIED')
# ('411869e3-a95c-4b76-b247-a801a05c07be', 'MRC-003660', datetime.datetime(2024, 1, 31, 0, 10, 1), 'POS', 'CARD_TRANSACTION', Decimal('143199.99'), 'SUCCESS', 'POS', 'OGUN', 'PREMIUM')
# ('a505cca1-48ac-45a5-b4d0-3e416140b463', 'MRC-009111', datetime.datetime(2024, 1, 31, 0, 10, 22), 'BILLS', 'ELECTRICITY', Decimal('17889.35'), 'SUCCESS', 'WEB', 'ENUGU', 'PREMIUM')
# ('c4e6150e-5ff8-4d79-97e1-10907781d9da', 'MRC-008568', datetime.datetime(2024, 1, 31, 0, 10, 25), 'AIRTIME', 'DATA_PURCHASE', Decimal('2045.93'), 'FAILED', 'APP', 'IBADAN', 'VERIFIED')
# ('e2148358-8935-4503-a3b2-aa3e81f4f4d7', 'MRC-002126', datetime.datetime(2024, 1, 31, 0, 10, 26), 'KYC', 'VERIFICATION_COMPLETED', Decimal('0.0'), 'SUCCESS', 'APP', 'PORT_HARCOURT', 'VERIFIED')
# ('c5004902-ebf8-4c9c-9bbd-a3ff7db0bac8', 'MRC-006083', datetime.datetime(2024, 1, 31, 0, 10, 44), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal
# ('cc5de32b-b379-473b-8dac-b14802b9ad5b', 'MRC-002133', datetime.datetime(2024, 1, 31, 0, 12, 50), 'POS', 'CARD_TRANSACTION', Decimal('406765.69'), 'SUCCESS', 'POS', 'LAGOS', 'VERIFIED')
# ('1bde0b4a-0993-4bb9-8409-6be7dad2846b', 'MRC-003166', datetime.datetime(2024, 1, 31, 0, 12, 55), 'POS', 'CASH_WITHDRAWAL', Decimal('12296.07'), 'SUCCESS', 'POS', 'KANO', 'VERIFIED')
# ('8a6db7b9-9b31-423b-90a6-ae49315660ea', 'MRC-004124', datetime.datetime(2024, 1, 31, 0, 13, 7), 'SAVINGS', 'INTEREST_CREDIT', Decimal('284999.22'), 'SUCCESS', 'APP', 'LAGOS', 'STARTER')
# ('4eeca104-a256-4a68-8954-4af8291a76c1', 'MRC-001184', datetime.datetime(2024, 1, 31, 0, 13, 15), 'POS', 'CARD_TRANSACTION', Decimal('277948.09'), 'SUCCESS', 'POS', 'KANO', 'PREMIUM')
# ('74c812b7-e473-4b30-b107-0908ecd98f57', 'MRC-003598', datetime.datetime(2024, 1, 31, 0, 13, 18), 'POS', 'TRANSFER', Decimal('103373.5'), 'SUCCESS', 'POS', 'RIVERS', 'STARTER')
# ('57f742d5-3ece-46ba-ba61-2a2329fa71aa', 'MRC-009839', datetime.datetime(2024, 1, 31, 0, 13, 23), 'SAVINGS', 'WITHDRAWAL', Decimal('62263.35'), 'SUCCESS', 'USSD', 'KADUNA', 'VERIFIED')
# ('cd06de70-b637-46f9-8b00-bf8d14ad0fc0', 'MRC-001098', datetime.datetime(2024, 1, 31, 0, 13, 26), 'POS', 'CASH_WITHDRAWAL', Decimal('33800.88'), 'SUCCESS', 'POS', 'OGUN', 'PREMIUM')
# ('911484d3-8a43-4f5c-aaf9-13e8fd1daaba', 'MRC-006132', datetime.datetime(2024, 1, 31, 0, 13, 48), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('215.32'), 'SUCCESS', 'POS', 'PORT_HARCOURT', 'VERIFIED')
# ('d0ad78a2-d11e-4ff3-a432-8be8fd37b004', 'MRC-005120', datetime.datetime(2024, 1, 31, 0, 14, 9), 'CARD_PAYMENT', 'INVOICE_PAYMENT', Decimal('103407.38'), 'FAILED', 'APP', 'ABUJA', 'STARTER')
# ('d1db293b-52c8-4758-a0a9-62f1c0b6cab4', 'MRC-007923', datetime.datetime(2024, 1, 31, 0, 14, 47), 'POS', 'TRANSFER', Decimal('152669.34'), 'SUCCESS', 'POS', 'IBADAN', 'VERIFIED')
# ('1db14fd7-526c-4cd4-adc4-b71e98fe70d5', 'MRC-000993', datetime.datetime(2024, 1, 31, 0, 14, 48), 'CARD_PAYMENT', 'INVOICE_PAYMENT', Decimal('700386.74'), 'SUCCESS', 'WEB', 'ABUJA', 'STARTER')
# ('109ea866-baca-4113-85eb-c02a51f96350', 'MRC-001276', datetime.datetime(2024, 1, 31, 0, 14, 57), 'MONIEBOOK', 'INVENTORY_UPDATE', Decimal('11895.46'), 'SUCCESS', 'OFFLINE', 'DELTA', 'VERIFIED')
# ('1024dc02-ba7e-4c0e-b7aa-38c62f3ec794', 'MRC-004855', datetime.datetime(2024, 1, 31, 0, 15, 24), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('2542.79'), 'SUCCESS', 'POS', 'PORT_HARCOURT', 'VERIFIED')
# ('6b870464-c438-44cb-95f7-457d5676c4c0', 'MRC-006584', datetime.datetime(2024, 1, 31, 0, 15, 26), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('1656.58'), 'SUCCESS', 'USSD', 'LAGOS', 'PREMIUM')
# ('404dc7e0-07cc-4d7b-8675-dc109bc1489e', 'MRC-000678', datetime.datetime(2024, 1, 31, 0, 15, 41), 'BILLS', 'WATER', Decimal('36570.64'), 'SUCCESS', 'POS', 'LAGOS', 'STARTER')
# ('4690ba8c-177b-43db-9c48-b9f29f75462e', 'MRC-003464', datetime.datetime(2024, 1, 31, 0, 15, 56), 'MONIEBOOK', 'INVENTORY_UPDATE', Decimal('3029.47'), 'PENDING', 'APP', 'LAGOS', 'VERIFIED')
# ('e2da6564-bd85-4b24-a84e-67e969f2d052', 'MRC-003884', datetime.datetime(2024, 1, 31, 0, 15, 59), 'SAVINGS', 'AUTO_SAVE', Decimal('14761.8'), 'SUCCESS', 'USSD', 'KADUNA', 'PREMIUM')
# ('882a6ee1-94e8-4dd0-bd84-9246bd9998e1', 'MRC-007900', datetime.datetime(2024, 1, 31, 0, 16, 14), 'POS', 'CARD_TRANSACTION', Decimal('210733.32'), 'SUCCESS', 'POS', 'RIVERS', 'PREMIUM')
# ('2e94945a-1830-4018-a6c4-0d8c431bdf07', 'MRC-005135', datetime.datetime(2024, 1, 31, 0, 16, 18), 'POS', 'CARD_TRANSACTION', Decimal('487.16'), 'SUCCESS', 'POS', 'KADUNA', 'PREMIUM')
# ('4b3bb3b4-4e07-45f1-a393-5f99ff6c2f9e', 'MRC-007844', datetime.datetime(2024, 1, 31, 0, 16, 27), 'MONIEBOOK', 'INVENTORY_UPDATE', Decimal('49458.8'), 'SUCCESS', 'OFFLINE', 'ABUJA', 'STARTER')
# ('fc0fc267-5f30-47b7-a585-e7a9a3300ab9', 'MRC-000290', datetime.datetime(2024, 1, 31, 0, 16, 41), 'POS', 'CARD_TRANSACTION', Decimal('145312.89'), 'SUCCESS', 'POS', 'IBADAN', 'PREMIUM')
# ('7faaaed6-18fb-4fad-a185-d95513fc57a1', 'MRC-009671', datetime.datetime(2024, 1, 31, 0, 16, 42), 'BILLS', 'BETTING', Decimal('6416.8'), 'SUCCESS', 'WEB', 'PORT_HARCOURT', 'VERIFIED')
# ('ea8fbfe8-79d4-4495-9022-d9559f7f7ecd', 'MRC-000570', datetime.datetime(2024, 1, 31, 0, 16, 50), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('279.68'), 'SUCCESS', 'APP', 'PORT_HARCOURT', 'VERIFIED')
# ('7bc7a6d2-4f1c-4bab-9c9b-7f88bba9ca06', 'MRC-005858', datetime.datetime(2024, 1, 31, 0, 16, 58), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('1670.36'), 'SUCCESS', 'WEB', 'PORT_HARCOURT', 'VERIFIED')
# ('f32b1134-ef64-4a3f-aee0-017cac23f4e6', 'MRC-000537', datetime.datetime(2024, 1, 31, 0, 17, 42), 'POS', 'CARD_TRANSACTION', Decimal('137127.96'), 'SUCCESS', 'POS', 'ENUGU', 'VERIFIED')
# ('26745b94-a89f-4332-ac5e-bbc300b419c7', 'MRC-002427', datetime.datetime(2024, 1, 31, 0, 17, 53), 'MONIEBOOK', 'EXPENSE_LOGGED', Decimal('17716.31'), 'SUCCESS', 'APP', 'IBADAN', 'VERIFIED')
# ('8a214245-d5c1-496a-ac5b-0c14a786aa1e', 'MRC-000464', datetime.datetime(2024, 1, 31, 0, 18, 22), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('565.79'), 'SUCCESS', 'APP', 'PORT_HARCOURT', 'STARTER')
# ('0120307b-c7f0-4342-b523-2dae11619a37', 'MRC-002034', datetime.datetime(2024, 1, 31, 0, 18, 24), 'POS', 'CASH_WITHDRAWAL', Decimal('171444.05'), 'SUCCESS', 'POS', 'ABUJA', 'VERIFIED')
# ('87a818ae-68d3-4cca-967c-a197da2773d7', 'MRC-008469', datetime.datetime(2024, 1, 31, 0, 18, 24), 'AIRTIME', 'AIRTIME_PURCHASE', Decimal('886.59'), 'SUCCESS', 'POS', 'OGUN', 'VERIFIED')
# ('c21ab7bb-b3db-412b-81d6-cd441ad20b06', 'MRC-003627', datetime.datetime(2024, 1, 31, 0, 18, 59), 'MONIEBOOK', 'SALE_RECORDED', Decimal('11699.41'), 'SUCCESS', 'APP', 'ENUGU', 'VERIFIED')
# ('9d2c6f69-e3fc-4f29-99d9-91078f5370de', 'MRC-009883', datetime.datetime(2024, 1, 31, 0, 19, 1), 'CARD_PAYMENT', 'SUPPLIER_PAYMENT', Decimal('161444.74'), 'SUCCESS', 'POS', 'RIVERS', 'VERIFIED')

# %%
top_merchant_query = """
CREATE VIEW top_merchant AS
select merchant_id, sum(amount) AS total_volume from merchant_activity_records
where status  = 'SUCCESS'
group by merchant_id
order by total_volume desc
limit 1;
"""

# Execute the SQL
cursor.execute(top_merchant_query)
conn.commit()  # commit changes

print("View created successfully!")
# Out:
# View created successfully!

# %%
product_adoption = """
SELECT product, COUNT(DISTINCT merchant_id) AS merchant_product_count
FROM merchant_activity_records
group by product
order by merchant_product_count desc;
"""

# Execute the SQL
cursor.execute(product_adoption)
conn.commit()  # commit changes

# %%
cursor.close()
conn.close()

# %% [markdown]
# # Create rest api that calls each view

# %%
from flask import Flask, jsonify, request

# Create the Flask app
app = Flask(__name__)

# %%
# Define a GET route
@app.route('/analytics/top-merchant', methods=['GET'])
def greet():
    # Get optional query parameter ?name=
    name = request.args.get('name', 'World')
    return jsonify({"message": f"Hello, {name}!"})

# %%
# GET endpoint to fetch all users
@app.route("/analytics/top-merchant", methods=["GET"])
def get_top_merchant():
    try:
        conn = get_db_connection()
        cursor = conn.cursor()
        cursor.execute("SELECT * FROM top_merchant;")
        response = cursor.fetchall()
        cursor.close()
        conn.close()
        return jsonify(response)
    except Exception as e:
        return jsonify({"error": str(e)}), 500

# %%
app.run(debug=True)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
#  * Restarting with watchdog (windowsapi)
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\sashe\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Automate view generation

# %%
import os

input_folder = "views/"

# get all files in input folder path
files = [
    input_folder+f for f in os.listdir(input_folder)
    if os.path.isfile(os.path.join(input_folder, f))
]

# clean non-numeric data in "amount" column, null "merchant_id", non-date type in "event_timestamp" and write cleaned data
for filename in files:
    with open(filename, "r") as file:
        content = file.read()
# Out:
# drop view if exists failure_rates;
# CREATE VIEW failure_rates AS
# SELECT product,
#     ROUND(
#         100.0 * SUM(CASE WHEN status = 'FAILED' THEN 1 ELSE 0 END) / COUNT(*),
#         1
#     ) AS failure_rate
# FROM merchant_activity_records
# where status = 'SUCCESS' or status = 'FAILED'
# group by product
# order by failure_rate desc;
